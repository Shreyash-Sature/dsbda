# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
df=pd.read_csv("titanic.csv")

# %%
df.info

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
grouped_data=df.groupby('Sex')['Age']

# %%
summary=grouped_data.describe()

# %%
summary
# Out:
#         count       mean        std   min   25%        50%    75%   max
# Sex
# female   56.0  25.058457  11.903499  2.00  17.0  27.000000  29.25  58.0
# male    100.0  29.868017  13.511006  0.83  22.0  28.141508  34.25  71.0

# %%
print("mean", df['Age'].mean())
print("median", df['Age'].median())
print("mode", df['Age'].mode())
print("std", df['Age'].std())
print("min", df['Age'].min())
# Out:
# mean 28.141507936507935
# median 28.141507936507935
# mode 0    28.141508
# Name: Age, dtype: float64
# std 13.123651589964874
# min 0.83

# %%
summary_2=grouped_data.agg(['mean','median'])

# %%
summary_2
# Out:
#              mean     median
# Sex
# female  25.058457  27.000000
# male    29.868017  28.141508

# %%
age_list=grouped_data.apply(list)
age_list
# Out:
# Sex
# female    [38.0, 26.0, 35.0, 27.0, 14.0, 4.0, 58.0, 14.0...
# male      [22.0, 35.0, 28.141507936507935, 54.0, 2.0, 20...
# Name: Age, dtype: object

# %%
grouped_data2=df.groupby('Sex')['Fare']
new_summary=grouped_data2.describe()
new_summary
# Out:
#         count       mean        std    min     25%      50%      75%    max
# Sex
# female   56.0  28.460639  40.144759  7.225  9.7375  15.9250  26.8500  263.0
# male    100.0  27.912998  39.180974  6.750  7.9177  12.0125  34.4448  263.0

# %%
#IRIS DATASET

# %%
df1=pd.read_csv("iris.csv")

# %%
grouped_data1=df1.groupby('Species')
summary1=grouped_data1.describe()
summary1
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
#can skip 
for spec , data in grouped_data1:
    print("Species=",spec)
    print(data.describe())
# Out:
# Species= Iris-setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
# Species= Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# ...

# %%
Species_list=grouped_data1.apply(list)
Species_list
# Out:
# Species
# Iris-setosa        [Id, SepalLengthCm, SepalWidthCm, PetalLengthC...
# Iris-versicolor    [Id, SepalLengthCm, SepalWidthCm, PetalLengthC...
# Iris-virginica     [Id, SepalLengthCm, SepalWidthCm, PetalLengthC...
# dtype: object
